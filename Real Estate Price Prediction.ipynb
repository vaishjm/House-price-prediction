# %% [markdown]
# # Real Estate Price Prediction

# %%
import pandas as pd

# %%
housing = pd.read_csv('data.csv')

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.281285
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702605
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Train-Test Splitting

# %%
import numpy as np

# %%
"""def split_train_test(data, test_ratio):
    #seed fixes the dataset even if shuffled many times
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data)*test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]"""
# Out:
# 'def split_train_test(data, test_ratio):\n    #seed fixes the dataset even if shuffled many times\n    np.random.seed(42)\n    shuffled = np.random.permutation(len(data))\n    test_set_size = int(len(data)*test_ratio)\n    test_indices = shuffled[:test_set_size]\n    train_indices = shuffled[test_set_size:]\n    return data.iloc[train_indices], data.iloc[test_indices]'

# %%
#train_set, test_set = split_train_test(housing, 0.2)

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}")
# Out:
# Rows in train set: 404
# Rows in test set: 102

# %% [markdown]
# CHAS feature has only 35 entries = 1, what if all of them go to test set? and model not able to pridict that case

# %% [markdown]
# data should  learn from all the types of features, specially important one

# %% [markdown]
# Sampling Technique - Stratified sampling

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split  = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['CHAS']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
 #95/7 and 376/2 have data in proportion

# %%
housing = strat_train_set.copy()

# %% [markdown]
# # Correlation

# %%
corr_matrix = housing.corr()
#corr with output feature
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.676608
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %% [markdown]
# RN and ZN showing high +ve corr
# LSTAT showing stong -ve corr

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['MEDV', 'RM', 'ZN', 'LSTAT']
scatter_matrix(housing[attributes], figsize = (12,8 ) )
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind = 'scatter', x='RM', y='MEDV', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %% [markdown]
#  remove outliers,
#  and capping at MEDV = 50 as rooms increasing price is same at MEDV = 50

# %% [markdown]
# try out Attribute combinations (new feature creation)

# %%
#1) tax per room

housing['TAXRM'] = housing['TAX']/housing['RM']

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
corr_matrix = housing.corr()
#corr with output feature
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.676608
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.525213
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing.plot(kind = 'scatter', x='TAXRM', y='MEDV', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='TAXRM', ylabel='MEDV'>

# %%
housing = strat_train_set.drop('MEDV', axis=1)
housing_lables = strat_train_set['MEDV'].copy()

# %% [markdown]
# # Missing Attribute

# %%
# take care of missing attribute
#1. get rid of missing data points
#2. get rid of whole attribute
#3. replace them with possible value (0 mean median)

# %%
#option 1
a = housing.dropna(subset=['RM'])
a.shape
# Out:
# (400, 13)

# %%
#option 2
housing.drop('RM', axis=1 ).shape
# Out:
# (404, 12)

# %%
median = housing['RM'].median()

# %%
housing['RM'].fillna(median) #option 3
# note that the original housing data will remain unchanged
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     6.210
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing.shape
# Out:
# (404, 13)

# %%
housing.describe()#before imputation
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.276232
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712270
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.877250
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median')
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21000e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
X = imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(X, columns= housing.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.275577
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.708757
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# # Scikit-learn Design

# %% [raw]
# Primarily three types of objects
# 1. Estimators - estimates some parameter based on dataset.
# eg. imputer has a fit method and transform method.
# fits the dataset and calculates internal parameters.
#
#
# 2. Transformers - transform method takes input and returns
# output based on learnings from fit(). it also has a convenience
# function called fit_tranform.
#
#
# 3. Predicators - LinearRegression model is an example of predictor.
# fit() and predict() are two common functons. also gives score()
# function which will evalute the predictions.

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# Primarily two types
# 1. Min-Max scaling (Normalization)
#      (value-min)/(max-min)
#     class - MinMaxScaler
#
# 2. Standardization
#     (value-mean)/std
#     class - Standard Scaler

# %% [markdown]
# # Creating a Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy = 'median')),
    # add as many as you want in your pipeline
    ('std_scaler', StandardScaler())
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing)

# %%
housing_num_tr
#numpy array - predictors take it as input
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# # Selecting a desired model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model = LinearRegression()
#model_name = 'LinearRegression'
#model = DecisionTreeRegressor()
#model_name = 'DecisionTree'
model = RandomForestRegressor()
model_name = 'RandomForest'
model.fit(housing_num_tr, housing_lables)
# Out:
# RandomForestRegressor()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_lables.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.148, 25.491, 16.268, 23.275, 23.543])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# # Evalute the model

# %%
from sklearn.metrics import mean_squared_error

# %%
housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_lables, housing_predictions)

# %%
rmse = np.sqrt(lin_mse)

# %%
rmse
# Out:
# 4.863459670297951

# %% [markdown]
# # better evalution technique - cross validation

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model,housing_num_tr,housing_lables, scoring='neg_mean_squared_error',cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.8788865 , 2.93882215, 4.48949355, 2.64840263, 3.1758539 ,
#        2.8104789 , 4.35986898, 3.44591406, 3.0812069 , 4.12458847])

# %%
def print_scores(scores, model):
    print('Scores:',scores)
    Mean = scores.mean()
    print('Mean: ',scores.mean())
    Standard_Deviation= scores.std()
    print('Standard Deviation: ',scores.std())
    f = open("model_output.txt", "a")
    f.write(f"\n{model}\n")
    f.write(f"Mean: {Mean}\n")
    f.write(f"Standard Deviation: {Standard_Deviation}\n")
    f.close()

# %%
print_scores(rmse_scores, model_name)
# Out:
# Scores: [2.8788865  2.93882215 4.48949355 2.64840263 3.1758539  2.8104789
#  4.35986898 3.44591406 3.0812069  4.12458847]
# Mean:  3.3953516048361214
# Standard Deviation:  0.6468240619818649

# %% [markdown]
# # Saving the model

# %%
from joblib import dump, load
dump(model, 'model.joblib')
# Out:
# ['model.joblib']

# %% [markdown]
# # Testing the model on test data

# %%
X_test = strat_test_set.drop('MEDV', axis=1)
Y_test = strat_test_set['MEDV'].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 2.8203855632679358
